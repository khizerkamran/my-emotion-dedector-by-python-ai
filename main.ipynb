# %%
'''
Emotion Detection Using AI
'''

#USAGE : python test.py

from keras.models import load_model
from time import sleep
from keras.preprocessing.image import img_to_array
from keras.preprocessing import image
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
classifier =load_model('./Emotion_Detection.h5')

class_labels = ['Angry','Happy','Neutral','Sad','Surprise']

cap = cv2.VideoCapture(0)



while True:
    # Grab a single frame of video
    ret, frame = cap.read()
    labels = []
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray,1.3,5)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h,x:x+w]
        roi_gray = cv2.resize(roi_gray,(48,48),interpolation=cv2.INTER_AREA)


        if np.sum([roi_gray])!=0:
            roi = roi_gray.astype('float')/255.0
            roi = img_to_array(roi)
            roi = np.expand_dims(roi,axis=0)

        # make a prediction on the ROI, then lookup the class

            preds = classifier.predict(roi)[0]
            print("\nprediction = ",preds)
            label=class_labels[preds.argmax()]
            print("\nprediction max = ",preds.argmax())
            print("\nlabel = ",label)
            label_position = (x,y)
            cv2.putText(frame,label,label_position,cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
        else:
            cv2.putText(frame,'No Face Found',(20,60),cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
        print("\n\n")
    cv2.imshow('Emotion Detector',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# prediction =  [0.1369146  0.12559138 0.21420121 0.51104254 0.01225034]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15605769 0.1607264  0.24070413 0.4137065  0.0288053 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15605769 0.1607264  0.24070413 0.4137065  0.0288053 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.1745581  0.19801073 0.23863184 0.34592515 0.04287417]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.1745581  0.19801073 0.23863184 0.34592515 0.04287417]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.17055313 0.18966378 0.23183368 0.36790672 0.04004266]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14613739 0.15200363 0.20104867 0.4820458  0.01876453]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14613739 0.15200363 0.20104867 0.4820458  0.01876453]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14891578 0.13639605 0.19988826 0.49437883 0.02042107]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16821909 0.12526609 0.22026905 0.46795636 0.01828935]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16821909 0.12526609 0.22026905 0.46795636 0.01828935]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16482377 0.11947186 0.29654968 0.20275302 0.21640164]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.16482377 0.11947186 0.29654968 0.20275302 0.21640164]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.16947909 0.10504272 0.2650088  0.42453098 0.03593836]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16947909 0.10504272 0.2650088  0.42453098 0.03593836]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14371578 0.05455539 0.35730278 0.22492893 0.21949713]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.12891985 0.04517969 0.41611642 0.21188161 0.19790246]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.12891985 0.04517969 0.41611642 0.21188161 0.19790246]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.1572847  0.15800014 0.32623088 0.26909766 0.08938663]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.15396668 0.13947316 0.3445434  0.31645352 0.04556314]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.15396668 0.13947316 0.3445434  0.31645352 0.04556314]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.16068229 0.08599325 0.40217027 0.26772794 0.08342626]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14062986 0.0775014  0.4263429  0.2261825  0.12934327]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14062986 0.0775014  0.4263429  0.2261825  0.12934327]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14300478 0.09001667 0.42023426 0.22027197 0.12647237]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14616874 0.10428703 0.4010566  0.22585869 0.12262895]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14616874 0.10428703 0.4010566  0.22585869 0.12262895]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.15826528 0.13553753 0.3545935  0.22240423 0.1291995 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14346795 0.0962797  0.39693022 0.20534308 0.15797909]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14346795 0.0962797  0.39693022 0.20534308 0.15797909]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.12743509 0.09219334 0.37039062 0.188049   0.221932  ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.12743509 0.09219334 0.37039062 0.188049   0.221932  ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.2207958  0.07052454 0.24103604 0.36440185 0.10324182]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.2207958  0.07052454 0.24103604 0.36440185 0.10324182]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18263917 0.10343805 0.25205585 0.37317234 0.08869465]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18263917 0.10343805 0.25205585 0.37317234 0.08869465]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18919016 0.11371671 0.22038051 0.43700626 0.0397063 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18919016 0.11371671 0.22038051 0.43700626 0.0397063 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.1583637  0.08296802 0.35185933 0.32760856 0.07920035]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.1583637  0.08296802 0.35185933 0.32760856 0.07920035]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.16160293 0.1434206  0.19695804 0.47571522 0.02230327]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16160293 0.1434206  0.19695804 0.47571522 0.02230327]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16482592 0.15825284 0.23281609 0.41662267 0.02748245]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.12877738 0.39717126 0.19684346 0.25657782 0.02063011]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.12877738 0.39717126 0.19684346 0.25657782 0.02063011]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.12930974 0.33920205 0.243094   0.2605185  0.02787566]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.14483333 0.28240448 0.22448422 0.32605952 0.02221848]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14483333 0.28240448 0.22448422 0.32605952 0.02221848]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.12849015 0.32151854 0.26398024 0.24825045 0.0377606 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.12849015 0.32151854 0.26398024 0.24825045 0.0377606 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.2125734  0.06276495 0.27725846 0.3932601  0.05414313]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.2125734  0.06276495 0.27725846 0.3932601  0.05414313]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16706222 0.12867302 0.20230259 0.47621349 0.02574869]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18080568 0.11251195 0.20904286 0.4574633  0.04017617]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18080568 0.11251195 0.20904286 0.4574633  0.04017617]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15871458 0.10725439 0.2163336  0.48053753 0.03715993]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15871458 0.10725439 0.2163336  0.48053753 0.03715993]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18637285 0.10946167 0.20330617 0.4604719  0.04038738]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18637285 0.10946167 0.20330617 0.4604719  0.04038738]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.17698762 0.11225484 0.2045645  0.46904647 0.03714656]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.1755166  0.10947135 0.20719695 0.47092834 0.03688684]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.1755166  0.10947135 0.20719695 0.47092834 0.03688684]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18723063 0.5148725  0.09408075 0.19119488 0.01262124]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.18723063 0.5148725  0.09408075 0.19119488 0.01262124]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.12039229 0.6847477  0.07173461 0.11035192 0.01277344]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.2794227  0.16990156 0.16286384 0.371476   0.01633584]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.2794227  0.16990156 0.16286384 0.371476   0.01633584]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.21207379 0.51422334 0.08815205 0.17040056 0.01515024]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.45628965 0.23520845 0.08784008 0.19578214 0.0248797 ]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.45628965 0.23520845 0.08784008 0.19578214 0.0248797 ]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.53198856 0.11012422 0.10642072 0.22617951 0.02528694]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.40732116 0.12100722 0.14005284 0.31163082 0.01998799]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.40732116 0.12100722 0.14005284 0.31163082 0.01998799]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5517552  0.11138958 0.09764556 0.21450482 0.02470485]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5854827  0.07870848 0.09456352 0.21777922 0.02346614]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5854827  0.07870848 0.09456352 0.21777922 0.02346614]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.49830103 0.0783243  0.11769862 0.28591606 0.01975995]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.55386704 0.04974523 0.10648993 0.26913077 0.02076697]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.55386704 0.04974523 0.10648993 0.26913077 0.02076697]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.45148385 0.07365479 0.1301629  0.32652617 0.01817224]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.48781997 0.24948645 0.07390829 0.15966018 0.02912509]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.48781997 0.24948645 0.07390829 0.15966018 0.02912509]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.52988523 0.17676434 0.08380336 0.18191375 0.02763337]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5235472  0.17719552 0.0864818  0.18527387 0.02750164]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5235472  0.17719552 0.0864818  0.18527387 0.02750164]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.6002655  0.15613694 0.06603546 0.15047774 0.02708437]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5318425  0.151179   0.09049573 0.19986151 0.02662118]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5318425  0.151179   0.09049573 0.19986151 0.02662118]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5591575  0.16135629 0.07857922 0.17374021 0.02716686]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.45868424 0.08578293 0.13095175 0.29826525 0.02631591]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.45868424 0.08578293 0.13095175 0.29826525 0.02631591]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.6597889  0.11314502 0.06054123 0.14185621 0.02466862]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.43661222 0.07032318 0.13475984 0.3400787  0.01822599]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.43661222 0.07032318 0.13475984 0.3400787  0.01822599]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4032338  0.09063335 0.14245337 0.34715056 0.01652901]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3380577  0.13454288 0.1623354  0.3490911  0.01597286]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.3380577  0.13454288 0.1623354  0.3490911  0.01597286]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.3204097  0.15606499 0.15414125 0.3505353  0.01884872]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.41461802 0.08674165 0.14033185 0.34106648 0.01724203]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.41461802 0.08674165 0.14033185 0.34106648 0.01724203]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.41856685 0.12331825 0.13112359 0.30683243 0.02015887]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4507639  0.12567407 0.11923967 0.28271478 0.02160755]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4507639  0.12567407 0.11923967 0.28271478 0.02160755]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.50115055 0.25276107 0.06620415 0.15218128 0.02770292]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.43174502 0.19098169 0.10528021 0.2496383  0.02235472]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.43174502 0.19098169 0.10528021 0.2496383  0.02235472]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4611259  0.10047442 0.11968014 0.29977983 0.01893975]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.35969105 0.28233498 0.10218257 0.23545147 0.0203399 ]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.35969105 0.28233498 0.10218257 0.23545147 0.0203399 ]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.40278938 0.19820325 0.11076555 0.26763615 0.02060569]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.33327517 0.2836971  0.11526772 0.24803858 0.01972141]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.33327517 0.2836971  0.11526772 0.24803858 0.01972141]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.35847834 0.17410703 0.13146742 0.31670827 0.01923897]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.2845699  0.31988057 0.11917357 0.25249147 0.0238844 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.2845699  0.31988057 0.11917357 0.25249147 0.0238844 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.15076208 0.19271424 0.20355359 0.43347287 0.01949717]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.1727921  0.33276007 0.16671723 0.31482425 0.01290633]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.1727921  0.33276007 0.16671723 0.31482425 0.01290633]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.27178845 0.4644578  0.07970777 0.16249734 0.02154869]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.29000944 0.1821383  0.14699422 0.36226612 0.018592  ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.29000944 0.1821383  0.14699422 0.36226612 0.018592  ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.33951676 0.27681315 0.11042608 0.2500203  0.02322376]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.27133754 0.40841362 0.10091021 0.20113045 0.01820822]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.27133754 0.40841362 0.10091021 0.20113045 0.01820822]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.25528935 0.4618741  0.09273443 0.1742171  0.01588504]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.31012675 0.33100462 0.10619067 0.23192172 0.0207562 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.31012675 0.33100462 0.10619067 0.23192172 0.0207562 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.2900734  0.49514875 0.0659597  0.12866062 0.02015753]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.33296883 0.2608476  0.1310414  0.25096682 0.02417526]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.33296883 0.2608476  0.1310414  0.25096682 0.02417526]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.43306708 0.3183974  0.0685397  0.15061213 0.02938366]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4135165  0.33444962 0.06856153 0.15615022 0.02732217]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4135165  0.33444962 0.06856153 0.15615022 0.02732217]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3517628  0.4237705  0.06228175 0.1393968  0.02278819]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.39160368 0.20935038 0.1275497  0.24422792 0.02726836]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.39160368 0.20935038 0.1275497  0.24422792 0.02726836]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4411111  0.19778064 0.10842957 0.22917415 0.02350444]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4644098  0.1560408  0.11264064 0.2393586  0.02755015]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4573401  0.19867465 0.10134567 0.20858748 0.03405211]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.23731375 0.05706867 0.20629881 0.4793613  0.01995751]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.23731375 0.05706867 0.20629881 0.4793613  0.01995751]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.23598039 0.03339209 0.2323882  0.46765926 0.03058006]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.24575837 0.04134728 0.22379066 0.46603638 0.02306723]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.24575837 0.04134728 0.22379066 0.46603638 0.02306723]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.23505652 0.04338069 0.21361879 0.49044955 0.01749441]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.25780168 0.0418818  0.20863627 0.47328123 0.01839897]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.25780168 0.0418818  0.20863627 0.47328123 0.01839897]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.23390473 0.06535198 0.20675904 0.4738136  0.02017065]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.23390473 0.06535198 0.20675904 0.4738136  0.02017065]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.39952263 0.21891585 0.10970142 0.24834612 0.02351398]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.46550888 0.2224807  0.09101301 0.19484654 0.02615085]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.46550888 0.2224807  0.09101301 0.19484654 0.02615085]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3807331  0.25537226 0.11128472 0.22930618 0.02330372]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3745835  0.15244262 0.13404623 0.31518736 0.02374021]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3745835  0.15244262 0.13404623 0.31518736 0.02374021]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.43919525 0.20884003 0.1019702  0.22349085 0.02650368]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.48272908 0.11429812 0.11408896 0.26648173 0.02240211]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.48272908 0.11429812 0.11408896 0.26648173 0.02240211]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.49595636 0.10547152 0.11567636 0.2584634  0.02443235]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.51337725 0.11832652 0.10810103 0.2352983  0.02489695]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.51337725 0.11832652 0.10810103 0.2352983  0.02489695]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.51238155 0.09835903 0.11693892 0.24189836 0.03042213]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.45298338 0.09280132 0.13520883 0.28742316 0.03158334]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.45298338 0.09280132 0.13520883 0.28742316 0.03158334]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.33284694 0.22158676 0.1557769  0.25062075 0.03916862]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3337218  0.15141119 0.1773316  0.3032912  0.0342443 ]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3337218  0.15141119 0.1773316  0.3032912  0.0342443 ]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.35462362 0.25273842 0.12635952 0.23562148 0.03065703]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3571024  0.3344723  0.09758867 0.17800985 0.03282687]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3571024  0.3344723  0.09758867 0.17800985 0.03282687]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.40399116 0.26120707 0.09784669 0.21025327 0.02670188]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.40476772 0.28318247 0.09259956 0.18615495 0.03329533]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.40476772 0.28318247 0.09259956 0.18615495 0.03329533]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.26080328 0.40360555 0.11300737 0.20501474 0.01756907]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.37006536 0.37840188 0.07214174 0.15362579 0.02576521]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.37006536 0.37840188 0.07214174 0.15362579 0.02576521]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.35311273 0.27234694 0.10873955 0.24408726 0.02171352]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4905671  0.18865284 0.0947065  0.195978   0.03009555]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.4905671  0.18865284 0.0947065  0.195978   0.03009555]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3840483  0.4019174  0.05992144 0.12853645 0.02557632]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.3921398  0.24971482 0.11654036 0.21209297 0.029512  ]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.3921398  0.24971482 0.11654036 0.21209297 0.029512  ]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.46038172 0.27063486 0.0749141  0.16466935 0.02939992]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.39543262 0.23176208 0.11252515 0.22260904 0.03767116]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.39543262 0.23176208 0.11252515 0.22260904 0.03767116]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.14330263 0.12494098 0.20485312 0.5081553  0.018748  ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14330263 0.12494098 0.20485312 0.5081553  0.018748  ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.22595981 0.03446698 0.32132468 0.3341502  0.08409829]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.22595981 0.03446698 0.32132468 0.3341502  0.08409829]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.252257   0.06897911 0.2542243  0.38041097 0.04412868]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.252257   0.06897911 0.2542243  0.38041097 0.04412868]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.1196055  0.04385478 0.4917577  0.24576235 0.09901972]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.1196055  0.04385478 0.4917577  0.24576235 0.09901972]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.13403329 0.10278223 0.42479438 0.26728114 0.07110901]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.11973497 0.06857382 0.48541236 0.27010635 0.05617253]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.11973497 0.06857382 0.48541236 0.27010635 0.05617253]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.58243155 0.13333096 0.07338949 0.19124037 0.01960761]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.58243155 0.13333096 0.07338949 0.19124037 0.01960761]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.40556443 0.33154014 0.07106748 0.17228243 0.01954542]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5352063  0.22875905 0.05963337 0.1546926  0.02170861]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.5352063  0.22875905 0.05963337 0.1546926  0.02170861]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.16688628 0.06423156 0.20160758 0.5439803  0.02329424]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16688628 0.06423156 0.20160758 0.5439803  0.02329424]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.5487642  0.18325834 0.07155026 0.17190765 0.0245195 ]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.58528394 0.17620817 0.06511786 0.15059333 0.02279668]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.58528394 0.17620817 0.06511786 0.15059333 0.02279668]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.14846088 0.14888605 0.20763308 0.47074848 0.02427157]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14846088 0.14888605 0.20763308 0.47074848 0.02427157]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15371604 0.14276801 0.21261448 0.46182284 0.02907859]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14971614 0.14408424 0.20827271 0.46884    0.0290869 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14971614 0.14408424 0.20827271 0.46884    0.0290869 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.42324683 0.26002294 0.10585949 0.18582636 0.02504447]
#
# prediction max =  0
#
# label =  Angry
#
#
#
#
# prediction =  [0.23002486 0.09339163 0.22574879 0.3603315  0.09050328]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.23002486 0.09339163 0.22574879 0.3603315  0.09050328]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.28081948 0.0653     0.22232923 0.2946301  0.1369212 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.28081948 0.0653     0.22232923 0.2946301  0.1369212 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.23018537 0.17326467 0.1899982  0.33991343 0.06663829]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.23018537 0.17326467 0.1899982  0.33991343 0.06663829]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.1389046  0.31549296 0.20860769 0.31231678 0.02467796]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.2047305  0.06890434 0.31525388 0.352154   0.05895729]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.2047305  0.06890434 0.31525388 0.352154   0.05895729]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.20430808 0.06322497 0.35697415 0.32644203 0.04905079]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.15100695 0.12449042 0.20170191 0.50275475 0.02004596]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15100695 0.12449042 0.20170191 0.50275475 0.02004596]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15315731 0.10057426 0.20894925 0.5181743  0.01914487]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15315731 0.10057426 0.20894925 0.5181743  0.01914487]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15493256 0.12062737 0.2123194  0.48920605 0.0229146 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14735158 0.10332796 0.20531659 0.522805   0.02119888]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14735158 0.10332796 0.20531659 0.522805   0.02119888]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15689933 0.16913836 0.21850587 0.4304291  0.02502736]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16014189 0.1656732  0.2299916  0.42135042 0.02284288]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.16014189 0.1656732  0.2299916  0.42135042 0.02284288]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.1701831  0.11522665 0.2616057  0.4258032  0.02718131]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18376318 0.09249822 0.22873981 0.468502   0.02649686]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.18376318 0.09249822 0.22873981 0.468502   0.02649686]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15123324 0.07714434 0.24359532 0.1850259  0.34300116]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.15123324 0.07714434 0.24359532 0.1850259  0.34300116]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.16357529 0.08253504 0.40256095 0.23289901 0.1184297 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.1464951  0.06452872 0.39200014 0.22116299 0.17581305]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.1464951  0.06452872 0.39200014 0.22116299 0.17581305]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.1551241  0.04949072 0.4087792  0.23280714 0.1537989 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.13341294 0.06133943 0.2995785  0.18559396 0.32007515]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.13341294 0.06133943 0.2995785  0.18559396 0.32007515]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.10450906 0.06242077 0.18422198 0.12317455 0.5256737 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.10435133 0.06653621 0.15459056 0.1104282  0.5640937 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.10435133 0.06653621 0.15459056 0.1104282  0.5640937 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.15337695 0.11527913 0.36082804 0.23473258 0.13578328]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.15337695 0.11527913 0.36082804 0.23473258 0.13578328]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.12512746 0.07907408 0.24587238 0.15885349 0.39107263]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.1401264  0.12913814 0.3237948  0.21036609 0.19657458]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.1401264  0.12913814 0.3237948  0.21036609 0.19657458]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14180678 0.09318453 0.21610843 0.16843422 0.38046607]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.14180678 0.09318453 0.21610843 0.16843422 0.38046607]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.16200796 0.08511458 0.23442933 0.18874313 0.32970506]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.14830613 0.09557404 0.25100863 0.18157364 0.3235375 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.14830613 0.09557404 0.25100863 0.18157364 0.3235375 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.16991068 0.0750269  0.3185944  0.23065895 0.20580907]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.15089937 0.12279716 0.27247825 0.23660955 0.21721564]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.15089937 0.12279716 0.27247825 0.23660955 0.21721564]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.17837678 0.1082363  0.26430315 0.38578525 0.0632985 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14035887 0.09268237 0.24284305 0.16914286 0.35497287]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.14035887 0.09268237 0.24284305 0.16914286 0.35497287]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.12539113 0.08721424 0.24495775 0.16152021 0.3809167 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.12539113 0.08721424 0.24495775 0.16152021 0.3809167 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.12490211 0.14654288 0.3436476  0.21813935 0.16676803]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14472319 0.09777048 0.2290186  0.1828285  0.34565923]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.14472319 0.09777048 0.2290186  0.1828285  0.34565923]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.169143   0.07207804 0.35598806 0.22854851 0.17424238]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14877954 0.0712784  0.39351246 0.22382401 0.1626056 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.10949222 0.08914119 0.54167956 0.19563903 0.06404804]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.10949222 0.08914119 0.54167956 0.19563903 0.06404804]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.11239816 0.09807128 0.5250618  0.20332448 0.0611443 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.10699556 0.06133425 0.59036094 0.18826698 0.0530423 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.10699556 0.06133425 0.59036094 0.18826698 0.0530423 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.10986323 0.06658795 0.5874168  0.18838832 0.0477437 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.12882309 0.05563809 0.55219907 0.21132205 0.05201773]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.12882309 0.05563809 0.55219907 0.21132205 0.05201773]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14525387 0.05127721 0.5215752  0.22696523 0.05492841]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14588349 0.05351431 0.4620899  0.22641161 0.11210068]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14588349 0.05351431 0.4620899  0.22641161 0.11210068]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.15460847 0.05798896 0.3859729  0.23301302 0.16841668]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.1458435  0.10906981 0.27096236 0.18311067 0.29101372]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.1458435  0.10906981 0.27096236 0.18311067 0.29101372]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.13869332 0.07458266 0.2532397  0.17819268 0.3552916 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.14363326 0.08842609 0.19580337 0.15084262 0.42129463]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.14363326 0.08842609 0.19580337 0.15084262 0.42129463]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.1649298  0.092298   0.21664776 0.17461167 0.35151276]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.15423635 0.08374719 0.23086666 0.17254862 0.35860118]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.15423635 0.08374719 0.23086666 0.17254862 0.35860118]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.12746985 0.07732422 0.20585474 0.14803378 0.4413174 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.15089744 0.07500301 0.25482476 0.18787442 0.3314004 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.15089744 0.07500301 0.25482476 0.18787442 0.3314004 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.13881335 0.08049043 0.2193018  0.15913518 0.40225932]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.17041185 0.13077433 0.31934655 0.25606024 0.12340696]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.17041185 0.13077433 0.31934655 0.25606024 0.12340696]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.13791405 0.17226742 0.3568962  0.29348865 0.0394337 ]
#
# prediction max =  2
#
# label =  Neutral

# %%
from keras.applications import MobileNet
from keras.models import Sequential,Model 
from keras.layers import Dense,Dropout,Activation,Flatten,GlobalAveragePooling2D
from keras.layers import Conv2D,MaxPooling2D,ZeroPadding2D
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator

# MobileNet is designed to work with images of dim 224,224
img_rows,img_cols = 224,224

MobileNet = MobileNet(weights='imagenet',include_top=False,input_shape=(img_rows,img_cols,3))

# Here we freeze the last 4 layers
# Layers are set to trainable as True by default

for layer in MobileNet.layers:
    layer.trainable = True

# Let's print our layers
for (i,layer) in enumerate(MobileNet.layers):
    print(str(i),layer.__class__.__name__,layer.trainable)

def addTopModelMobileNet(bottom_model, num_classes):
    """creates the top or head of the model that will be 
    placed ontop of the bottom layers"""

    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024,activation='relu')(top_model)
    
    top_model = Dense(1024,activation='relu')(top_model)
    
    top_model = Dense(512,activation='relu')(top_model)
    
    top_model = Dense(num_classes,activation='softmax')(top_model)

    return top_model

num_classes = 5

FC_Head = addTopModelMobileNet(MobileNet, num_classes)

model = Model(inputs = MobileNet.input, outputs = FC_Head)

print(model.summary())

train_data_dir = '/Users/durgeshthakur/Deep Learning Stuff/Emotion Classification/fer2013/train'
validation_data_dir = '/Users/durgeshthakur/Deep Learning Stuff/Emotion Classification/fer2013/validation'

train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=30,
                    width_shift_range=0.3,
                    height_shift_range=0.3,
                    horizontal_flip=True,
                    fill_mode='nearest'
                                   )

validation_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 32

train_generator = train_datagen.flow_from_directory(
                        train_data_dir,
                        target_size = (img_rows,img_cols),
                        batch_size = batch_size,
                        class_mode = 'categorical'
                        )

validation_generator = validation_datagen.flow_from_directory(
                            validation_data_dir,
                            target_size=(img_rows,img_cols),
                            batch_size=batch_size,
                            class_mode='categorical')

from keras.optimizers import RMSprop,Adam
from keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau

checkpoint = ModelCheckpoint(
                             'emotion_face_mobilNet.h5',
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(
                          monitor='val_loss',
                          min_delta=0,
                          patience=10,
                          verbose=1,restore_best_weights=True)

learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=5, 
                                            verbose=1, 
                                            factor=0.2, 
                                            min_lr=0.0001)

callbacks = [earlystop,checkpoint,learning_rate_reduction]

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['accuracy']
              )

nb_train_samples = 24176
nb_validation_samples = 3006

epochs = 25

history = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples//batch_size,
            epochs=epochs,
            callbacks=callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples//batch_size)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-945d2ec908fc> in <module>
# ----> 1 from keras.applications import MobileNet
#       2 from keras.models import Sequential,Model
#       3 from keras.layers import Dense,Dropout,Activation,Flatten,GlobalAveragePooling2D
#       4 from keras.layers import Conv2D,MaxPooling2D,ZeroPadding2D
#       5 from keras.layers.normalization import BatchNormalization
#
# ImportError: cannot import name 'MobileNet' from 'keras.applications' (c:\users\fazz communication\appdata\local\programs\python\python38\lib\site-packages\keras\applications\__init__.py)
